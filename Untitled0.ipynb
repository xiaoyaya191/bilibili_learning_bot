# %% [markdown]
# <a href="https://colab.research.google.com/github/xiaoyaya191/bilibili_learning_bot/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/xiaoyaya191/bilibili_learning_bot
# Out:
# Cloning into 'bilibili_learning_bot'...
# remote: Enumerating objects: 1489, done.
# remote: Counting objects: 100% (194/194), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 1489 (delta 125), reused 60 (delta 60), pack-reused 1295 (from 3)
# Receiving objects: 100% (1489/1489), 266.51 MiB | 26.22 MiB/s, done.
# Resolving deltas: 100% (533/533), done.
# Updating files: 100% (1010/1010), done.

# %% [markdown]
# ### 安装Buildozer和依赖
#
# 为了编译APK，我们需要安装 `buildozer`。它需要一些系统级别的依赖，所以我们先安装它们。

# %%
# 安装Buildozer所需的依赖
# !sudo apt update
# !sudo apt install -y git zip unzip openjdk-17-jdk python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libssl-dev libffi-dev libgdbm-dev libsqlite3-dev libbz2-dev libreadline-dev liblzma-dev
# !pip install buildozer
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [105 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,158 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,524 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,314 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.7 MB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,836 kB]
# Get:17 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [44.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,616 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [92.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,545 kB]
# Get:23 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,190 kB]
# Get:24 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [84.1 kB]
# Fetched 41.7 MB in 4s (10.7 MB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 137 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# autoconf is already the newest version (2.71-2).
# autoconf set to manually installed.
# libbz2-dev is already the newest version (1.0.8-5build1).
# libbz2-dev set to manually installed.
# libffi-dev is already the newest version (3.4.2-4).
# libffi-dev set to manually installed.
# libreadline-dev is already the newest version (8.1.2-1).
# libreadline-dev set to manually installed.
# zip is already the newest version (3.0-12build2).
# git is already the newest version (1:2.34.1-1ubuntu1.17).
# liblzma-dev is already the newest version (5.2.5-2ubuntu1.1).
# liblzma-dev set to manually installed.
# unzip is already the newest version (6.0-26ubuntu3.2).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# The following package was automatically installed and is no longer required:
#   libpkgconf3
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   at-spi2-core fonts-dejavu-core fonts-dejavu-extra gsettings-desktop-schemas
#   javascript-common libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatspi2.0-0
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libjs-sphinxdoc libjs-underscore libncurses-dev libncurses6 libncursesw6
#   libpython3.10 libpython3.10-dev libpython3.10-minimal libpython3.10-stdlib
#   librsvg2-common libsqlite3-0 libssl3 libtinfo6 libxcomposite1 libxt-dev
#   libxtst6 libxxf86dga1 openjdk-17-jre python3-dev python3-pkg-resources
#   python3-setuptools python3-wheel python3.10 python3.10-dev
#   python3.10-minimal r-base-core session-migration x11-utils
# Suggested packages:
#   apache2 | lighttpd | httpd gvfs ncurses-doc sqlite3-doc libssl-doc
#   libtool-doc gcj-jdk libxt-doc openjdk-17-demo openjdk-17-source visualvm
#   python-setuptools-doc python3.10-venv python3.10-doc binfmt-support elpa-ess
#   r-doc-info | r-doc-pdf r-mathlib r-base-html mesa-utils
# Recommended packages:
#   r-base-dev r-doc-html
# The following packages will be REMOVED:
#   pkgconf r-base-dev
# The following NEW packages will be installed:
#   at-spi2-core fonts-dejavu-core fonts-dejavu-extra gsettings-desktop-schemas
#   javascript-common libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatspi2.0-0
#   libgail-common libgail18 libgdbm-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libjs-sphinxdoc libjs-underscore libncursesw5-dev
#   librsvg2-common libtool libxcomposite1 libxt-dev libxtst6 libxxf86dga1
#   openjdk-17-jdk openjdk-17-jre pkg-config python3-dev python3-pip
#   python3-setuptools python3-wheel python3.10-dev session-migration x11-utils
# The following packages will be upgraded:
#   libncurses-dev libncurses5-dev libncurses6 libncursesw6 libpython3.10
#   libpython3.10-dev libpython3.10-minimal libpython3.10-stdlib libsqlite3-0
#   libsqlite3-dev libssl-dev libssl3 libtinfo6 python3-pkg-resources python3.10
#   python3.10-minimal r-base-core
# 17 upgraded, 36 newly installed, 2 to remove and 119 not upgraded.
# Need to get 61.3 MB of archives.
# After this operation, 37.6 MB of additional disk space will be used.
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ r-base-core 4.6.1-2.2204.0 [30.3 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 pkg-config amd64 0.29.2-1ubuntu3 [48.2 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-dev amd64 3.10.12-1~22.04.16 [4,766 kB]
# Get:4 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-pkg-resources all 68.1.2-2~jammy3 [216 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10 amd64 3.10.12-1~22.04.16 [1,950 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl-dev amd64 3.0.2-0ubuntu1.26 [2,377 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl3 amd64 3.0.2-0ubuntu1.26 [1,906 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10 amd64 3.10.12-1~22.04.16 [508 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-stdlib amd64 3.10.12-1~22.04.16 [1,850 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10-minimal amd64 3.10.12-1~22.04.16 [2,254 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-minimal amd64 3.10.12-1~22.04.16 [817 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libncurses5-dev amd64 6.3-2ubuntu0.2 [788 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libncurses-dev amd64 6.3-2ubuntu0.2 [381 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libncurses6 amd64 6.3-2ubuntu0.2 [111 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libncursesw6 amd64 6.3-2ubuntu0.2 [147 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtinfo6 amd64 6.3-2ubuntu0.2 [105 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsqlite3-dev amd64 3.37.2-2ubuntu0.7 [847 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsqlite3-0 amd64 3.37.2-2ubuntu0.7 [643 kB]
# Get:19 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-setuptools all 68.1.2-2~jammy3 [465 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 javascript-common all 11+nmu1 [5,936 B]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgdbm-dev amd64 1.23-1 [117 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjs-underscore all 1.13.2~dfsg-2 [118 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjs-sphinxdoc all 4.3.2-1 [139 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libncursesw5-dev amd64 6.3-2ubuntu0.2 [790 B]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtool all 2.4.6-15build2 [164 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jre amd64 17.0.19+10-1~22.04.2 [238 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jdk amd64 17.0.19+10-1~22.04.2 [2,477 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10-dev amd64 3.10.12-1~22.04.16 [508 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-dev amd64 3.10.6-1~22.04.1 [26.0 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel all 0.37.1-2ubuntu0.22.04.1 [32.0 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.7 [1,306 kB]
# Fetched 61.3 MB in 2s (38.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 53.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 118243 files and directories currently installed.)
# Removing r-base-dev (4.6.0-4.2204.0) ...
# dpkg: pkgconf: dependency problems, but removing anyway as you requested:
#  libsndfile1-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libmkl-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libglib2.0-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libfontconfig-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#
# Removing pkgconf (1.8.0-1) ...
# Removing 'diversion of /usr/bin/pkg-config to /usr/bin/pkg-config.real by pkgconf'
# Removing 'diversion of /usr/share/aclocal/pkg.m4 to /usr/share/aclocal/pkg.real.m4 by pkgconf'
# Removing 'diversion of /usr/share/man/man1/pkg-config.1.gz to /usr/share/man/man1/pkg-config.real.1.gz by pkgconf'
# Removing 'diversion of /usr/share/pkg-config-crosswrapper to /usr/share/pkg-config-crosswrapper.real by pkgconf'
# Selecting previously unselected package pkg-config.
# (Reading database ... 118220 files and directories currently installed.)
# Preparing to unpack .../pkg-config_0.29.2-1ubuntu3_amd64.deb ...
# Unpacking pkg-config (0.29.2-1ubuntu3) ...
# Preparing to unpack .../libpython3.10-dev_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking libpython3.10-dev:amd64 (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../libpython3.10_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking libpython3.10:amd64 (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../libssl-dev_3.0.2-0ubuntu1.26_amd64.deb ...
# Unpacking libssl-dev:amd64 (3.0.2-0ubuntu1.26) over (3.0.2-0ubuntu1.23) ...
# Preparing to unpack .../libssl3_3.0.2-0ubuntu1.26_amd64.deb ...
# Unpacking libssl3:amd64 (3.0.2-0ubuntu1.26) over (3.0.2-0ubuntu1.23) ...
# Setting up libssl3:amd64 (3.0.2-0ubuntu1.26) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# (Reading database ... 118235 files and directories currently installed.)
# Preparing to unpack .../0-python3.10_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking python3.10 (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../1-libpython3.10-stdlib_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking libpython3.10-stdlib:amd64 (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../2-python3.10-minimal_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking python3.10-minimal (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../3-libpython3.10-minimal_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking libpython3.10-minimal:amd64 (3.10.12-1~22.04.16) over (3.10.12-1~22.04.15) ...
# Preparing to unpack .../4-libncurses5-dev_6.3-2ubuntu0.2_amd64.deb ...
# Unpacking libncurses5-dev:amd64 (6.3-2ubuntu0.2) over (6.3-2ubuntu0.1) ...
# Preparing to unpack .../5-libncurses-dev_6.3-2ubuntu0.2_amd64.deb ...
# Unpacking libncurses-dev:amd64 (6.3-2ubuntu0.2) over (6.3-2ubuntu0.1) ...
# Preparing to unpack .../6-libncurses6_6.3-2ubuntu0.2_amd64.deb ...
# Unpacking libncurses6:amd64 (6.3-2ubuntu0.2) over (6.3-2ubuntu0.1) ...
# Preparing to unpack .../7-libncursesw6_6.3-2ubuntu0.2_amd64.deb ...
# Unpacking libncursesw6:amd64 (6.3-2ubuntu0.2) over (6.3-2ubuntu0.1) ...
# Preparing to unpack .../8-libtinfo6_6.3-2ubuntu0.2_amd64.deb ...
# Unpacking libtinfo6:amd64 (6.3-2ubuntu0.2) over (6.3-2ubuntu0.1) ...
# Setting up libtinfo6:amd64 (6.3-2ubuntu0.2) ...
# (Reading database ... 118235 files and directories currently installed.)
# Preparing to unpack .../00-libsqlite3-dev_3.37.2-2ubuntu0.7_amd64.deb ...
# Unpacking libsqlite3-dev:amd64 (3.37.2-2ubuntu0.7) over (3.37.2-2ubuntu0.5) ...
# Preparing to unpack .../01-libsqlite3-0_3.37.2-2ubuntu0.7_amd64.deb ...
# Unpacking libsqlite3-0:amd64 (3.37.2-2ubuntu0.7) over (3.37.2-2ubuntu0.5) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../02-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../03-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../04-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../05-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../06-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../07-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../08-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../09-javascript-common_11+nmu1_all.deb ...
# Unpacking javascript-common (11+nmu1) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../10-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../11-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../12-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../13-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../14-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../15-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../16-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../17-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../18-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../19-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../20-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../21-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgdbm-dev:amd64.
# Preparing to unpack .../22-libgdbm-dev_1.23-1_amd64.deb ...
# Unpacking libgdbm-dev:amd64 (1.23-1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../23-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../24-libjs-underscore_1.13.2~dfsg-2_all.deb ...
# Unpacking libjs-underscore (1.13.2~dfsg-2) ...
# Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../25-libjs-sphinxdoc_4.3.2-1_all.deb ...
# Unpacking libjs-sphinxdoc (4.3.2-1) ...
# Selecting previously unselected package libncursesw5-dev:amd64.
# Preparing to unpack .../26-libncursesw5-dev_6.3-2ubuntu0.2_amd64.deb ...
# Unpacking libncursesw5-dev:amd64 (6.3-2ubuntu0.2) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../27-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../28-libtool_2.4.6-15build2_all.deb ...
# Unpacking libtool (2.4.6-15build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../29-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package openjdk-17-jre:amd64.
# Preparing to unpack .../30-openjdk-17-jre_17.0.19+10-1~22.04.2_amd64.deb ...
# Unpacking openjdk-17-jre:amd64 (17.0.19+10-1~22.04.2) ...
# Selecting previously unselected package openjdk-17-jdk:amd64.
# Preparing to unpack .../31-openjdk-17-jdk_17.0.19+10-1~22.04.2_amd64.deb ...
# Unpacking openjdk-17-jdk:amd64 (17.0.19+10-1~22.04.2) ...
# Selecting previously unselected package python3.10-dev.
# Preparing to unpack .../32-python3.10-dev_3.10.12-1~22.04.16_amd64.deb ...
# Unpacking python3.10-dev (3.10.12-1~22.04.16) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../33-python3-dev_3.10.6-1~22.04.1_amd64.deb ...
# Unpacking python3-dev (3.10.6-1~22.04.1) ...
# Preparing to unpack .../34-python3-pkg-resources_68.1.2-2~jammy3_all.deb ...
# Unpacking python3-pkg-resources (68.1.2-2~jammy3) over (59.6.0-1.2ubuntu0.22.04.3) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../35-python3-setuptools_68.1.2-2~jammy3_all.deb ...
# Unpacking python3-setuptools (68.1.2-2~jammy3) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../36-python3-wheel_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../37-python3-pip_22.0.2+dfsg-1ubuntu0.7_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.7) ...
# Preparing to unpack .../38-r-base-core_4.6.1-2.2204.0_amd64.deb ...
# Unpacking r-base-core (4.6.1-2.2204.0) over (4.6.0-4.2204.0) ...
# Setting up python3-pkg-resources (68.1.2-2~jammy3) ...
# Setting up javascript-common (11+nmu1) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up python3-setuptools (68.1.2-2~jammy3) ...
# Setting up libtool (2.4.6-15build2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libsqlite3-0:amd64 (3.37.2-2ubuntu0.7) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Setting up libsqlite3-dev:amd64 (3.37.2-2ubuntu0.7) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libncurses6:amd64 (6.3-2ubuntu0.2) ...
# Setting up r-base-core (4.6.1-2.2204.0) ...
# Installing new version of config file /etc/R/Makeconf ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up libssl-dev:amd64 (3.0.2-0ubuntu1.26) ...
# Setting up libpython3.10-minimal:amd64 (3.10.12-1~22.04.16) ...
# Setting up pkg-config (0.29.2-1ubuntu3) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.7) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libncursesw6:amd64 (6.3-2ubuntu0.2) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libgdbm-dev:amd64 (1.23-1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libjs-underscore (1.13.2~dfsg-2) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libncurses-dev:amd64 (6.3-2ubuntu0.2) ...
# Setting up libncursesw5-dev:amd64 (6.3-2ubuntu0.2) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up python3.10-minimal (3.10.12-1~22.04.16) ...
# Setting up libpython3.10-stdlib:amd64 (3.10.12-1~22.04.16) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libjs-sphinxdoc (4.3.2-1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libncurses5-dev:amd64 (6.3-2ubuntu0.2) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libpython3.10:amd64 (3.10.12-1~22.04.16) ...
# Setting up python3.10 (3.10.12-1~22.04.16) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up openjdk-17-jre:amd64 (17.0.19+10-1~22.04.2) ...
# Setting up openjdk-17-jdk:amd64 (17.0.19+10-1~22.04.2) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libpython3.10-dev:amd64 (3.10.12-1~22.04.16) ...
# Setting up python3.10-dev (3.10.12-1~22.04.16) ...
# Setting up python3-dev (3.10.6-1~22.04.1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.5) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Setting up at-spi2-core (2.44.0-3) ...
# Collecting buildozer
#   Downloading buildozer-1.6.0-py3-none-any.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.3/159.3 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pexpect in /usr/local/lib/python3.12/dist-packages (from buildozer) (4.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from buildozer) (26.2)
# Collecting cython<3.0 (from buildozer)
#   Downloading Cython-0.29.37-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect->buildozer) (0.7.0)
# Downloading buildozer-1.6.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.7/92.7 kB 8.0 MB/s eta 0:00:00
# Downloading Cython-0.29.37-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 19.2 MB/s eta 0:00:00
# Installing collected packages: cython, buildozer
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.12
#     Uninstalling Cython-3.0.12:
#       Successfully uninstalled Cython-3.0.12
# Successfully installed buildozer-1.6.0 cython-0.29.37

# %% [markdown]
# ### 切换到项目目录
#
# 现在我们需要进入 `bilibili_learning_bot` 目录，因为 `buildozer` 命令需要在项目根目录中运行。

# %%
# 切换到克隆的仓库目录
import os
os.chdir('bilibili_learning_bot')
print(f"当前工作目录: {os.getcwd()}")
# Out:
# 当前工作目录: /content/bilibili_learning_bot

# %%
# 运行buildozer编译APK
# 注意：这可能需要很长时间，并且可能会下载很多文件
# 如果这是第一次运行，可能需要多次执行此单元格来解决下载或配置问题。
# 增加log_level以获取更详细的错误信息
# !buildozer --verbose android debug
# Out:
# Streaming output truncated to the last 5000 lines.
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	[arm64-v8a] StaticLibrary  : libwebpdemux.a
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/libwebpdemux.a
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/llvm-ar crsD  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/libwebpdemux.a /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webpdemux/src/demux/anim_decode.o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webpdemux/src/demux/demux.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= cost.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/cost.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= cost_mips32.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_mips32.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_mips32.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/cost_mips32.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_mips32.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= cost_mips_dsp_r2.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_mips_dsp_r2.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_mips_dsp_r2.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/cost_mips_dsp_r2.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_mips_dsp_r2.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= cost_neon.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_neon.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_neon.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/cost_neon.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_neon.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= cost_sse2.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_sse2.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_sse2.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/cost_sse2.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/cost_sse2.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/enc.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= enc_mips32.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_mips32.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_mips32.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/enc_mips32.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_mips32.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= enc_mips_dsp_r2.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_mips_dsp_r2.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_mips_dsp_r2.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/enc_mips_dsp_r2.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_mips_dsp_r2.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= enc_msa.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_msa.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_msa.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/enc_msa.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_msa.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= enc_neon.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_neon.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_neon.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/enc_neon.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_neon.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= enc_sse2.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_sse2.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_sse2.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/enc_sse2.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_sse2.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= enc_sse41.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_sse41.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_sse41.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/enc_sse41.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/enc_sse41.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= lossless_enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/lossless_enc.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= lossless_enc_mips32.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_mips32.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_mips32.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/lossless_enc_mips32.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_mips32.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= lossless_enc_mips_dsp_r2.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_mips_dsp_r2.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_mips_dsp_r2.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/lossless_enc_mips_dsp_r2.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_mips_dsp_r2.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= lossless_enc_msa.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_msa.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_msa.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/lossless_enc_msa.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_msa.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= lossless_enc_neon.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_neon.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_neon.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/lossless_enc_neon.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_neon.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= lossless_enc_sse2.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_sse2.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_sse2.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/lossless_enc_sse2.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_sse2.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= lossless_enc_sse41.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_sse41.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_sse41.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/lossless_enc_sse41.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/lossless_enc_sse41.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= ssim.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/ssim.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/ssim.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/ssim.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/ssim.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= ssim_sse2.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/ssim_sse2.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/ssim_sse2.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/dsp/ssim_sse2.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/dsp/ssim_sse2.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= alpha_enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/alpha_enc.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/alpha_enc.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/enc/alpha_enc.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/alpha_enc.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= analysis_enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/analysis_enc.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/analysis_enc.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/enc/analysis_enc.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/analysis_enc.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= backward_references_cost_enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/backward_references_cost_enc.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/backward_references_cost_enc.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/enc/backward_references_cost_enc.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/backward_references_cost_enc.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= backward_references_enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/backward_references_enc.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/backward_references_enc.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/enc/backward_references_enc.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/backward_references_enc.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= config_enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/config_enc.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/config_enc.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/enc/config_enc.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/config_enc.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= cost_enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/cost_enc.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/cost_enc.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/enc/cost_enc.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/cost_enc.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= filter_enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/filter_enc.o
# [DEBUG]:   	/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -MMD -MP -MF /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/filter_enc.o.d -target aarch64-none-linux-android21 -fdata-sections -ffunction-sections -fstack-protector-strong -funwind-tables -no-canonical-prefixes  --sysroot /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot -g -Wno-invalid-command-line-argument -Wno-unused-command-line-argument  -D_FORTIFY_SOURCE=2 -fpic -O0 -UNDEBUG -fno-limit-debug-info  -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp   -DANDROID -Wall -DANDROID -DHAVE_MALLOC_H -DHAVE_PTHREAD -DWEBP_USE_THREAD -fvisibility=hidden -Wformat -Werror=format-security  -c  /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/jni/SDL2_image/external/libwebp/src/enc/filter_enc.c -o /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/filter_enc.o
# [DEBUG]:   	[arm64-v8a] Compile        : webp <= frame_enc.c
# [DEBUG]:   	rm -f /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/bootstrap_builds/sdl2/obj/local/arm64-v8a/objs-debug/webp/src/enc/frame_enc.o
# ...
#   878 |         b = PyUnicode_AS_UNICODE(text);
#       |           ^ ~~~~~~~~~~~~~~~~~~~~~~~~~~
# 6 warnings and 4 errors generated.
# error: command '/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang' failed with exit code 1
#
#
#   STDERR:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/bilibili_learning_bot/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py", line 1290, in <module>
#     main()
#   File "/content/bilibili_learning_bot/.buildozer/android/platform/python-for-android/pythonforandroid/entrypoints.py", line 18, in main
#     ToolchainCL()
#   File "/content/bilibili_learning_bot/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py", line 721, in __init__
#     getattr(self, command)(args)
#   File "/content/bilibili_learning_bot/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py", line 104, in wrapper_func
#     build_dist_from_args(ctx, dist, args)
#   File "/content/bilibili_learning_bot/.buildozer/android/platform/python-for-android/pythonforandroid/toolchain.py", line 163, in build_dist_from_args
#     build_recipes(build_order, python_modules, ctx,
#   File "/content/bilibili_learning_bot/.buildozer/android/platform/python-for-android/pythonforandroid/build.py", line 530, in build_recipes
#     recipe.build_arch(arch)
#   File "/content/bilibili_learning_bot/.buildozer/android/platform/python-for-android/pythonforandroid/recipe.py", line 1089, in build_arch
#     self.build_compiled_components(arch)
#   File "/content/bilibili_learning_bot/.buildozer/android/platform/python-for-android/pythonforandroid/recipe.py", line 1100, in build_compiled_components
#     shprint(hostpython, 'setup.py', self.build_cmd, '-v',
#   File "/content/bilibili_learning_bot/.buildozer/android/platform/python-for-android/pythonforandroid/logger.py", line 174, in shprint
#     for line in output:
#                 ^^^^^^
#   File "/root/.local/lib/python3.12/site-packages/sh/__init__.py", line 876, in __next__
#     self.wait()
#   File "/root/.local/lib/python3.12/site-packages/sh/__init__.py", line 793, in wait
#     self.handle_command_exit_code(exit_code)
#   File "/root/.local/lib/python3.12/site-packages/sh/__init__.py", line 820, in handle_command_exit_code
#     raise exc
# sh.ErrorReturnCode_1:
#
#   RAN: /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/hostpython3/desktop/hostpython3/native-build/root/usr/local/bin/python setup.py build_ext -v
#
#   STDOUT:
# ################################################
# #Attempting install of _rl_accel & pyHnj
# #extensions from '/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel'
# ################################################
# ################################################
# #Attempting install of _renderPM
# #extensions from '/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/renderPM'
# will use package libart 2.3.12
# # installing with freetype version 21
# ################################################
# not downloading T1 font curve files
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/hostpython3/desktop/hostpython3/native-build/root/usr/local/lib/python3.14/site-packages/setuptools/dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
# !!
#
#         ********************************************************************************
#         Please consider removing the following classifiers in favor of a SPDX license expression:
#
#         License :: OSI Approved :: BSD License
#
#         See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#         ********************************************************************************
#
# !!
#   self._finalize_license_expression()
# running build_ext
# building 'reportlab.lib._rl_accel' extension
# creating build/temp.linux-x86_64-cpython-314/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel
# /root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang -target aarch64-linux-android21 -fomit-frame-pointer -march=armv8-a -fPIC -target aarch64-linux-android21 -fomit-frame-pointer -march=armv8-a -fPIC -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/python3/arm64-v8a__ndk_target_21/python3/android-build/android-root/include/python3.14 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/python3/arm64-v8a__ndk_target_21/python3/android-build/android-root/include/python3.14 -fPIC -I/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/hostpython3/desktop/hostpython3/native-build/root/usr/local/include/python3.14 -c /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c -o build/temp.linux-x86_64-cpython-314/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.o
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:94:10: error: incomplete definition of type 'struct _frame'
#    94 |         py_frame->f_lineno = moduleLineno;
#       |         ~~~~~~~~^
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/python3/arm64-v8a__ndk_target_21/python3/android-build/android-root/include/python3.14/pytypedefs.h:22:16: note: forward declaration of 'struct _frame'
#    22 | typedef struct _frame PyFrameObject;
#       |                ^
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:121:10: warning: assigning to 'unsigned char *' from 'char *' converts between pointers to integer types where one is of the unique plain 'char' type and the other is not [-Wpointer-sign]
#   121 |                 inData = PyBytes_AsString(_o1);
#       |                        ^ ~~~~~~~~~~~~~~~~~~~~~
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:132:9: warning: assigning to 'unsigned char *' from 'char *' converts between pointers to integer types where one is of the unique plain 'char' type and the other is not [-Wpointer-sign]
#   132 |         inData = PyBytes_AsString(inObj);
#       |                ^ ~~~~~~~~~~~~~~~~~~~~~~~
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:221:10: warning: assigning to 'unsigned char *' from 'char *' converts between pointers to integer types where one is of the unique plain 'char' type and the other is not [-Wpointer-sign]
#   221 |                 inData = PyBytes_AsString(_o1);
#       |                        ^ ~~~~~~~~~~~~~~~~~~~~~
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:232:9: warning: assigning to 'unsigned char *' from 'char *' converts between pointers to integer types where one is of the unique plain 'char' type and the other is not [-Wpointer-sign]
#   232 |         inData = PyBytes_AsString(inObj);
#       |                ^ ~~~~~~~~~~~~~~~~~~~~~~~
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:586:10: warning: assigning to 'char *' from 'const char *' discards qualifiers [-Wincompatible-pointer-types-discards-qualifiers]
#   586 |                 encStr = PyUnicode_AsUTF8(_o2);
#       |                        ^ ~~~~~~~~~~~~~~~~~~~~~
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:834:2: warning: 'Py_UNICODE' is deprecated [-Wdeprecated-declarations]
#   834 |         Py_UNICODE *b;
#       |         ^
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/python3/arm64-v8a__ndk_target_21/python3/android-build/android-root/include/python3.14/cpython/unicodeobject.h:10:1: note: 'Py_UNICODE' has been explicitly marked deprecated here
#    10 | Py_DEPRECATED(3.13) typedef wchar_t Py_UNICODE;
#       | ^
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/python3/arm64-v8a__ndk_target_21/python3/android-build/android-root/include/python3.14/pyport.h:281:54: note: expanded from macro 'Py_DEPRECATED'
#   281 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#       |                                                      ^
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:877:6: error: call to undeclared function 'PyUnicode_GET_SIZE'; ISO C99 and later do not support implicit function declarations [-Wimplicit-function-declaration]
#   877 |         n = PyUnicode_GET_SIZE(text);
#       |             ^
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:877:6: note: did you mean 'PyDict_GET_SIZE'?
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/python3/arm64-v8a__ndk_target_21/python3/android-build/android-root/include/python3.14/cpython/dictobject.h:53:26: note: 'PyDict_GET_SIZE' declared here
#    53 | static inline Py_ssize_t PyDict_GET_SIZE(PyObject *op) {
#       |                          ^
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:878:6: error: call to undeclared function 'PyUnicode_AS_UNICODE'; ISO C99 and later do not support implicit function declarations [-Wimplicit-function-declaration]
#   878 |         b = PyUnicode_AS_UNICODE(text);
#       |             ^
# /content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a/build/other_builds/reportlab/arm64-v8a__ndk_target_21/reportlab/src/rl_addons/rl_accel/_rl_accel.c:878:4: error: incompatible integer to pointer conversion assigning to 'Py_UNICODE *' (aka 'unsigned int *') from 'int' [-Wint-conversion]
#   878 |         b = PyUnicode_AS_UNICODE(text);
#       |           ^ ~~~~~~~~~~~~~~~~~~~~~~~~~~
# 6 warnings and 4 errors generated.
# error: command '/root/.buildozer/android/platform/android-ndk-r28c/toolchains/llvm/prebuilt/linux-x86_64/bin/clang' failed with exit code 1
#
#
#   STDERR:
#
# # Command failed: ('/usr/bin/python3', '-m', 'pythonforandroid.toolchain', 'create', '--dist_name=bililibot', '--bootstrap=sdl2', '--requirements=python3,kivy,pyjnius,openssl,ffmpeg,pillow,requests,urllib3,jinja2,colorama,flask,flask-cors,httpx,pydantic,qrcode,imageio-ffmpeg,yt-dlp,python-docx,reportlab,bilibili-api-python', '--arch=arm64-v8a', '--copy-libs', '--color=always', '--storage-dir=/content/bilibili_learning_bot/.buildozer/android/platform/build-arm64-v8a', '--ndk-api=21', '--ignore-setup-py', '--debug')
# # Error code: 1
# # ENVIRONMENT:
# #     SHELL = '/bin/bash'
# #     COLAB_JUPYTER_TRANSPORT = 'ipc'
# #     CGROUP_MEMORY_EVENTS = '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events'
# #     VM_GCE_METADATA_HOST = '169.254.169.253'
# #     HOSTNAME = 'acffe3c5b1b7'
# #     MODEL_PROXY_HOST = 'https://mp.kaggle.net'
# #     LANGUAGE = 'en_US'
# #     TBE_RUNTIME_ADDR = '172.28.0.1:8011'
# #     GCE_METADATA_TIMEOUT = '3'
# #     COLAB_JUPYTER_IP = '172.28.0.12'
# #     KMP_LISTEN_PORT = '6000'
# #     TF_FORCE_GPU_ALLOW_GROWTH = 'true'
# #     ENV = '/root/.bashrc'
# #     PWD = '/content/bilibili_learning_bot'
# #     TBE_EPHEM_CREDS_ADDR = '172.28.0.1:8009'
# #     TBE_CREDS_ADDR = '172.28.0.1:8008'
# #     JPY_SESSION_NAME = 'https://github.com/xiaoyaya191/bilibili_learning_bot/blob/main/Untitled0.ipynb'
# #     COLAB_JUPYTER_TOKEN = ''
# #     LAST_FORCED_REBUILD = '20260508'
# #     TCLLIBPATH = '/usr/share/tcltk/tcllib1.20'
# #     COLAB_KERNEL_MANAGER_PROXY_HOST = '172.28.0.12'
# #     UV_BUILD_CONSTRAINT = ''
# #     USE_AUTH_EPHEM = '1'
# #     COLAB_WARMUP_DEFAULTS = '1'
# #     HOME = '/root'
# #     LANG = 'en_US.UTF-8'
# #     COLAB_ENABLE_SSH = '1'
# #     MODEL_PROXY_API_KEY = 'colab:CiQA2m4/Rm83Xhp64U1KnYHQuUsFDNnoJGO99l4C0n5MR52/Rh8ShAEAeHUIZaNrc7Jl/IBAy0ELYbwx3rdk1WXKWjUHx1xLjtycHP6whLAJW9m+Nn4T/kcD+ay16i85p4Gb2LHn6/JvcirwW/mysEWtShUKx6YgzvXGeqFrSTjymX23mUKlSp1zCWHSb9KHrfKccO4nJVsDAwKXw3ouTg/pKSYFzZxosElTIPU='
# #     CLOUDSDK_CONFIG = '/content/.config'
# #     UV_SYSTEM_PYTHON = 'true'
# #     COLAB_RELEASE_TAG = 'release-colab-external-images_20260805-060052_RC00'
# #     PYDEVD_USE_FRAME_EVAL = 'NO'
# #     KMP_TARGET_PORT = '9000'
# #     CLICOLOR = '1'
# #     KMP_EXTRA_ARGS = ('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 '
#  '--tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-kkb-use1b0-2f0ss3j81g6ui '
#  '--tunnel_background_save_delay=10s '
#  '--tunnel_periodic_background_save_frequency=30m0s '
#  '--enable_output_coalescing=true --output_coalescing_required=true '
#  '--use_oneplatform_for_bg_save=true ')
# #     UV_INSTALL_DIR = '/usr/local/bin'
# #     COLAB_KERNEL_MANAGER_PROXY_PORT = '6000'
# #     CLOUDSDK_PYTHON = 'python3'
# #     ENABLE_DIRECTORYPREFETCHER = '1'
# #     NO_GCE_CHECK = 'False'
# #     JPY_PARENT_PID = '105'
# #     COLAB_NOTEBOOK_ID = 'https://github.com/xiaoyaya191/bilibili_learning_bot/blob/main/Untitled0.ipynb'
# #     PYTHONPATH = '/env/python'
# #     TERM = 'xterm-color'
# #     GIT_PAGER = 'cat'
# #     SHLVL = '0'
# #     PAGER = 'cat'
# #     COLAB_LANGUAGE_SERVER_PROXY = '/usr/colab/bin/language_service'
# #     UV_CONSTRAINT = ''
# #     PYTHONUTF8 = '1'
# #     MPLBACKEND = 'module://matplotlib_inline.backend_inline'
# #     COLAB_GPU = ''
# #     GCS_READ_CACHE_BLOCK_SIZE_MB = '16'
# #     LC_ALL = 'en_US.UTF-8'
# #     _PYVIZ_COMMS_INSTALLED = '1'
# #     COLAB_FILE_HANDLER_ADDR = 'localhost:3453'
# #     PATH = '/root/.buildozer/android/platform/apache-ant-1.9.4/bin:/opt/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin'
# #     COLAB_IMAGE_TYPE = 'cpu'
# #     PYTHONWARNINGS = 'ignore:::pip._internal.cli.base_command'
# #     DEBIAN_FRONTEND = 'noninteractive'
# #     COLAB_BACKEND_VERSION = 'next'
# #     OLDPWD = '/'
# #     _ = '/usr/bin/python3'
# #     PACKAGES_PATH = '/root/.buildozer/android/packages'
# #     ANDROIDSDK = '/root/.buildozer/android/platform/android-sdk'
# #     ANDROIDNDK = '/root/.buildozer/android/platform/android-ndk-r28c'
# #     ANDROIDAPI = '33'
# #     ANDROIDMINAPI = '21'
# #
# # Buildozer failed to execute the last command
# # The error might be hidden in the log above this error
# # Please read the full log, and search for it before
# # raising an issue with buildozer itself.
# # In case of a bug report, please add a full log with log_level = 2

# %%
import requests

# 定义API URL
api_url = "https://uapis.cn/api/v1/network/myip"

try:
    # 发送GET请求
    response = requests.get(api_url)
    response.raise_for_status()  # 检查请求是否成功

    # 解析JSON响应并打印
    data = response.json()
    print("机器IP地址信息:")
    display(data)

except requests.exceptions.RequestException as e:
    print(f"请求失败: {e}")
except ValueError as e:
    print(f"JSON解析失败: {e}")
# Out:
# 机器IP地址信息:
# {'ip': '34.106.156.71',
#  'beginip': '34.106.0.0',
#  'endip': '34.106.255.255',
#  'region': '美国 Utah Salt Lake City',
#  'isp': 'GOOGLE-CLOUD-PLATFORM',
#  'asn': 'AS396982',
#  'llc': '谷歌',
#  'latitude': 40.76078,
#  'longitude': -111.891052}

# %%
import sys
# !{sys.executable} -m pip install requests retrying tqdm

# %% [markdown]
# I've modified the download logic to use Python's `requests` library with a retry mechanism and a progress bar to handle potential network issues more gracefully. This should help in successfully downloading `freetype-2.14.1.tar.gz`.

# %%
import os
import requests
from retrying import retry
from tqdm.notebook import tqdm

# 定义下载URL和目标文件名
download_url = "https://download.savannah.gnu.org/releases/freetype/freetype-2.14.1.tar.gz"
filename = "freetype-2.14.1.tar.gz"

# buildozer 的缓存目录通常在项目根目录下的 .buildozer/downloads/
# 如果当前工作目录已经是 'bilibili_learning_bot'，则直接构建路径
buildozer_downloads_path = os.path.join('.buildozer', 'downloads')

# 确保缓存目录存在
os.makedirs(buildozer_downloads_path, exist_ok=True)

# 构建完整的目标文件路径
target_filepath = os.path.join(buildozer_downloads_path, filename)

def retry_if_exception(exception):
    """Return True if we should retry (in this case when it's an HTTPError or a ConnectionError), False otherwise"""
    return isinstance(exception, (requests.exceptions.HTTPError, requests.exceptions.ConnectionError))

@retry(retry_on_exception=retry_if_exception, stop_max_attempt_number=5, wait_fixed=2000)
def download_file_with_retries(url, destination_path):
    print(f"Attempting to download {url} to {destination_path}")
    response = requests.get(url, stream=True, timeout=10) # Added timeout
    response.raise_for_status() # Raise an exception for HTTP errors

    total_size_in_bytes = int(response.headers.get('content-length', 0))
    block_size = 4096 # 4 Kibibytes
    progress_bar = tqdm(total=total_size_in_bytes, unit='iB', unit_scale=True)

    with open(destination_path, 'wb') as file:
        for data in response.iter_content(block_size):
            progress_bar.update(len(data))
            file.write(data)
    progress_bar.close()
    print("Download successful!")

# 检查文件是否已经存在，如果存在则跳过下载
if os.path.exists(target_filepath) and os.path.getsize(target_filepath) > 0:
    print(f"文件 '{filename}' 已经存在于 '{buildozer_downloads_path}' 且不为空，跳过下载。")
else:
    print(f"正在从 {download_url} 下载 '{filename}' 到 '{buildozer_downloads_path}'...")
    try:
        download_file_with_retries(download_url, target_filepath)
    except Exception as e:
        print(f"下载失败: {e}")

print("现在您可以再次尝试运行 buildozer 命令 (在 '52a69493' 单元格) 来继续构建过程了。")

# %% [markdown]
# 根据之前的日志，`buildozer` 在下载 `freetype-2.14.1.tar.gz` 时遇到了网络问题。我们将手动下载这个文件，并将其放置在 `buildozer` 的缓存目录中，以便 `buildozer` 可以在下次尝试构建时直接使用它。

# %%
import os

# 定义下载URL和目标文件名
download_url = "https://download.savannah.gnu.org/releases/freetype/freetype-2.14.1.tar.gz"
filename = "freetype-2.14.1.tar.gz"

# buildozer 的缓存目录通常在项目根目录下的 .buildozer/downloads/
# 如果当前工作目录已经是 'bilibili_learning_bot'，则直接构建路径
buildozer_downloads_path = os.path.join('.buildozer', 'downloads')

# 确保缓存目录存在
os.makedirs(buildozer_downloads_path, exist_ok=True)

# 构建完整的目标文件路径
target_filepath = os.path.join(buildozer_downloads_path, filename)

# 检查文件是否已经存在，如果存在则跳过下载
if os.path.exists(target_filepath):
    print(f"文件 '{filename}' 已经存在于 '{buildozer_downloads_path}'，跳过下载。")
else:
    print(f"正在从 {download_url} 下载 '{filename}' 到 '{buildozer_downloads_path}'...")
    # 使用 wget 命令下载文件
    # !wget -P {buildozer_downloads_path} {download_url}
    print("下载完成！")

print("现在您可以再次尝试运行 buildozer 命令 (在 '52a69493' 单元格) 来继续构建过程了。")
# Out:
# 正在从 https://download.savannah.gnu.org/releases/freetype/freetype-2.14.1.tar.gz 下载 'freetype-2.14.1.tar.gz' 到 '.buildozer/downloads'...
# --2026-08-08 06:08:54--  https://download.savannah.gnu.org/releases/freetype/freetype-2.14.1.tar.gz
# Resolving download.savannah.gnu.org (download.savannah.gnu.org)... 209.51.188.200, 2001:470:142:5::200
# Connecting to download.savannah.gnu.org (download.savannah.gnu.org)|209.51.188.200|:443... connected.
# HTTP request sent, awaiting response... 502 Bad Gateway
# 2026-08-08 06:09:02 ERROR 502: Bad Gateway.
#
# 下载完成！
# 现在您可以再次尝试运行 buildozer 命令 (在 '52a69493' 单元格) 来继续构建过程了。

# %% [markdown]
# ### 编译APK
#
# 最后，运行 `buildozer` 命令来编译debug版本的APK。这可能需要一些时间，因为它会下载Android SDK和NDK等工具。

# %% [markdown]
# 编译完成后，您将在 `bin/` 目录下找到生成的APK文件。
